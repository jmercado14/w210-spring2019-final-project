# %%
import numpy as np
import pandas as pd
import nltk
# nltk.download('punkt')
# nltk.download('stopwords')
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
# nltk.download('wordnet')
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer

import re
import networkx as nx
from sklearn.metrics.pairwise import cosine_similarity

import spacy
spacy.load('en')
from spacy.lang.en import English
parser = English()
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

import gensim
from gensim import corpora
import pickle

# %%
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)

en_stop = set(nltk.corpus.stopwords.words('english'))

def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
# load file
training_feedback = pd.read_csv('training_data/feedback_data_for_training.csv')

# %%
training_feedback
# Out:
#              source                                      feedback_text  \
# 0    team_generated  i have no idea how i’m doing so far. we’ve tur...
# 1    team_generated  i’d ask for more time from the TAs, or try to ...
# 2    team_generated  the way that they encourage lots of class disc...
# 3    team_generated  async is going pretty well, but not super appl...
# 4    team_generated    abe lincoln is the best professor i’ve ever had
# 5    team_generated                                        tech is bad
# 6    team_generated                                this is a great bot
# 7    team_generated  pretty well, actually! i think i’m finally get...
# 8    team_generated  the breakout sessions were very engaging, and ...
# 9    team_generated  one person dominated the full-class discussion...
# 10   team_generated  they’re fine. problem sets are really helpful,...
# 11   team_generated  async was okay. it felt superfluous though. it...
# 12   team_generated  i feel like we could use an extra TA - it woul...
# 13   team_generated  class is… not going well. i’m feeling a little...
# 14   team_generated  live session was good! lots of lively discussi...
# 15   team_generated  async was pretty repetitive. it felt like a lo...
# 16   team_generated  still haven’t gotten any feedback on assignmen...
# 17   team_generated  class is going well! i feel like i’m understan...
# 18   team_generated  it was good - it ran half an hour over, which ...
# 19   team_generated  it was good - it ran half an hour over, which ...
# 20   team_generated  async felt a little long this week, it didn’t ...
# 21   team_generated  the problem sets have been really difficult. i...
# 22   team_generated  live sessions have been running late recently,...
# 23   team_generated  class is going REALLY well right now. i’m real...
# 24   team_generated  i  thought the discussion was really productiv...
# 25   team_generated  it was okay. i feel like the async for the las...
# 26   team_generated  didn’t have any assignments this week, so all ...
# 27   team_generated  live session hasn’t really had anything to do ...
# 28   team_generated  haven't gotten any feedback on assignments yet...
# 29   team_generated            live session feels like a waste of time
# ..              ...                                                ...
# 163      class_recs  I found the decade old HBR articles worthless....
# 164      class_recs  I really wish the async was deeper. In my opin...
# 165      class_recs  The assignments currently aren’t something you...
# 166      class_recs  They’re nice guys, and working professionals i...
# 167      class_recs  Pretty hands-off. You're on your own. The cour...
# 168      class_recs                        Definitely not fully-baked.
# 169      class_recs  harder, largely because of how the assignments...
# 170      class_recs  he's good, not great. He has a math background...
# 171      class_recs  He doesn't spend much time talking code, which...
# 172      class_recs  He doesn't go into the math, preferring to foc...
# 173      class_recs               He is MVP - don't miss his classes.
# 174      class_recs  He provided examples from his job at Vox that ...
# 175      class_recs   He's focused more on the intuition and practi...
# 176      class_recs  He did get behind (2-3 weeks) for my section o...
# 177      class_recs  he is not a very good speaker. He speaks very ...
# 178      class_recs   really good, designed the whole course, hold ...
# 179      class_recs  office hours many times, and he is very clear ...
# 180      class_recs  He is very clear, engaging, gives good answers...
# 181      class_recs  the asyncs aren't very good for learning it on...
# 182      class_recs  terribly scoped home works.  I haven’t learned...
# 183      class_recs  faculty all have pooled office hours - so you ...
# 184      class_recs  He explains things well, and has a really good...
# 185      class_recs  He sometimes takes quite a while (measured in ...
# 186      class_recs                        relatively slow turnaround.
# 187      class_recs                                      very engaging
# 188      class_recs                                     great feedback
# 189      class_recs  he puts people on the spot during live session...
# 190      class_recs  usually provides feedback to homeworks in abou...
# 191      class_recs  I feel like the async content was more helpful...
# 192      class_recs  There's a huge amount of reading just to under...
#
#                topic                       sub_topic
# 0           feedback                 slow turnaround
# 1           feedback                 slow turnaround
# 2       live session                 good discussion
# 3              async  disconnected from live session
# 4         instructor                             NaN
# 5               tech                        negative
# 6               tech                        positive
# 7    course material                  understandable
# 8       live session                 good discussion
# 9       live session                      unbalanced
# 10          feedback                 slow turnaround
# 11             async  disconnected from live session
# 12          feedback                 slow turnaround
# 13   course material                       confusing
# 14      live session                 good discussion
# 15             async                     low quality
# 16          feedback                 slow turnaround
# 17          feedback                 slow turnaround
# 18      live session                 good discussion
# 19      live session            not keeping schedule
# 20             async  disconnected from live session
# 21       assignments                   too difficult
# 22      live session            not keeping schedule
# 23   course material                  understandable
# 24      live session                      unbalanced
# 25             async  disconnected from live session
# 26               NaN                             NaN
# 27             async  disconnected from live session
# 28          feedback                 slow turnaround
# 29      live session                     not helpful
# ..               ...                             ...
# 163      assignments                             NaN
# 164            async                             NaN
# 165      assignments                             NaN
# 166      instructors                             NaN
# 167      instructors                             NaN
# 168  course material                             NaN
# 169      assignments                             NaN
# 170      instructors                             NaN
# 171      instructors                             NaN
# 172      instructors                             NaN
# 173      instructors                             NaN
# 174      instructors                             NaN
# 175      instructors                             NaN
# 176         feedback                             NaN
# 177      instructors                             NaN
# 178      instructors                             NaN
# 179     office hours                             NaN
# 180      instructors                             NaN
# 181            async                             NaN
# 182      assignments                             NaN
# 183     office hours                             NaN
# 184      instructors                             NaN
# 185         feedback                             NaN
# 186      assignments                             NaN
# 187      instructors                             NaN
# 188         feedback                             NaN
# 189      instructors                             NaN
# 190         feedback                             NaN
# 191            async                             NaN
# 192      assignments                             NaN
#
# [193 rows x 4 columns]

# %%
topics = set(training_feedback.topic)
topics
# Out:
# {'assignments',
#  'async',
#  'course material',
#  'feedback',
#  'instructor',
#  'instructors',
#  'live session',
#  'misc',
#  nan,
#  'office hours',
#  'tech'}

# %%
for topic in topics:
    print ("Processing", topic)
    topic_subset = training_feedback[training_feedback.topic==topic]
    topic_text = topic_subset.feedback_text
    # print(text)
    
    chats_tokenized = []
    
    for t in topic_text:
        tokens = prepare_text_for_lda(t)
        chats_tokenized.append(tokens)
        
    dictionary = corpora.Dictionary(chats_tokenized)
    dictionary_filename = "topic_dictionaries/%s_dictionary_feedback.gensim" % (str(topic))
    corpus = [dictionary.doc2bow(text) for text in chats_tokenized]
    corpus_filename = "topic_corpi/%s_corpus_feedback.pkl" % (str(topic))
    

    pickle.dump(corpus, open(corpus_filename, 'wb'))
    dictionary.save(dictionary_filename)
# Out:
# Processing nan
# Processing misc
# Processing instructors
# Processing feedback
# Processing tech
# Processing async
# Processing assignments
# Processing instructor
# Processing office hours
# Processing live session
# Processing course material

# %%
NUM_TOPICS = 3
NUM_PASSES = 15

for topic in topics:
    print(topic)
    dictionary_filename = "topic_dictionaries/%s_dictionary_feedback.gensim" % (str(topic))
    dictionary = corpora.Dictionary.load(dictionary_filename)
    corpus_filename = "topic_corpi/%s_corpus_feedback.pkl" % (str(topic))
    with open(corpus_filename, 'rb') as f:
        corpus = pickle.load(f)
    if (len(dictionary) == 0):
        continue
    
    ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=NUM_PASSES)
    ldamodel_filename = 'topic_models/feedback_model%st_%sp.gensim' % (str(NUM_TOPICS), str(NUM_PASSES))
    ldamodel.save(ldamodel_filename)
    
    sub_topics = ldamodel.print_topics(num_words=5)
    for sub_topic in sub_topics:
        print(sub_topic)
# Out:
# nan
# misc
# (0, '0.038*"speaker" + 0.038*"really" + 0.038*"class" + 0.038*"assignment" + 0.038*"material"')
# (1, '0.075*"reading" + 0.041*"longer" + 0.041*"series" + 0.041*"opinion" + 0.041*"portion"')
# (2, '0.014*"impossible" + 0.014*"class" + 0.014*"reading" + 0.014*"overwhelm" + 0.014*"really"')
# (3, '0.068*"system" + 0.037*"especially" + 0.037*"understanding" + 0.037*"still" + 0.037*"algorithm"')
# (4, '0.050*"point" + 0.050*"workload" + 0.050*"grade" + 0.050*"pretty" + 0.050*"anything"')
# instructors
# (0, '0.048*"responsive" + 0.033*"class" + 0.033*"really" + 0.033*"instructor" + 0.033*"slack"')
# (1, '0.054*"class" + 0.038*"focus" + 0.038*"working" + 0.037*"people" + 0.021*"example"')
# (2, '0.036*"really" + 0.036*"enough" + 0.036*"ability" + 0.036*"speak" + 0.036*"comprehend"')
# (3, '0.037*"background" + 0.036*"class" + 0.020*"instructor" + 0.020*"great" + 0.020*"decent"')
# (4, '0.049*"engage" + 0.027*"prefer" + 0.027*"sessions" + 0.027*"conceptual" + 0.027*"understanding"')
# feedback
# (0, '0.048*"grade" + 0.033*"assignment" + 0.019*"might" + 0.018*"instructor" + 0.018*"responsive"')
# (1, '0.037*"question" + 0.037*"might" + 0.026*"grade" + 0.026*"instructor" + 0.015*"feedback"')
# (2, '0.083*"feedback" + 0.054*"assignment" + 0.039*"grade" + 0.031*"semester" + 0.024*"frustrate"')
# (3, '0.069*"feedback" + 0.040*"instructor" + 0.040*"semester" + 0.040*"final" + 0.030*"project"')
# (4, '0.062*"grade" + 0.052*"feedback" + 0.022*"receive" + 0.022*"get" + 0.022*"problem"')
# tech
# (0, '0.067*"video" + 0.051*"mobile" + 0.035*"experience" + 0.035*"async" + 0.034*"watch"')
# (1, '0.055*"audio" + 0.055*"speaker" + 0.055*"quality" + 0.054*"stuff" + 0.030*"focus"')
# (2, '0.092*"issue" + 0.048*"problem" + 0.048*"first" + 0.048*"homework" + 0.048*"logistical"')
# (3, '0.059*"great" + 0.039*"mobile" + 0.039*"section" + 0.038*"experience" + 0.038*"really"')
# (4, '0.064*"mobile" + 0.064*"discussion" + 0.035*"question" + 0.035*"put_litter_in_its_place" + 0.035*"matter"')
# async
# (0, '0.059*"async" + 0.040*"pretty" + 0.040*"quality" + 0.021*"asyncs" + 0.021*"angry"')
# (1, '0.055*"async" + 0.041*"discussion" + 0.029*"reading" + 0.029*"assignment" + 0.028*"found"')
# (2, '0.048*"class" + 0.034*"async" + 0.033*"textbook" + 0.018*"useless" + 0.018*"going"')
# (3, '0.085*"async" + 0.054*"session" + 0.043*"class" + 0.033*"little" + 0.033*"really"')
# (4, '0.056*"async" + 0.025*"really" + 0.025*"though" + 0.025*"quiz" + 0.025*"exercise"')
# assignments
# (0, '0.052*"assignment" + 0.040*"hard" + 0.028*"spend" + 0.027*"forever" + 0.027*"week"')
# (1, '0.066*"assignment" + 0.028*"instructor" + 0.028*"understand" + 0.028*"weekly" + 0.028*"problem"')
# (2, '0.044*"assignment" + 0.023*"async" + 0.023*"together" + 0.023*"anything" + 0.023*"commitment"')
# (3, '0.039*"really" + 0.027*"works" + 0.027*"learn" + 0.027*"reading" + 0.027*"understand"')
# (4, '0.036*"found" + 0.020*"class" + 0.020*"reading" + 0.020*"something" + 0.020*"level"')
# instructor
# (0, '0.031*"class" + 0.021*"generally" + 0.021*"style" + 0.012*"first" + 0.012*"would"')
# (1, '0.025*"really" + 0.024*"material" + 0.017*"class" + 0.017*"question" + 0.017*"instructor"')
# (2, '0.048*"class" + 0.025*"student" + 0.014*"would" + 0.014*"particularly" + 0.014*"responsive"')
# (3, '0.025*"class" + 0.024*"question" + 0.024*"slack" + 0.024*"consistently" + 0.014*"encourage"')
# (4, '0.031*"would" + 0.031*"class" + 0.031*"assignment" + 0.022*"really" + 0.022*"instructor"')
# office hours
# (0, '0.053*"hours" + 0.053*"office" + 0.053*"helpful" + 0.053*"knowledgeable" + 0.053*"clear"')
# (1, '0.056*"explain" + 0.056*"things" + 0.055*"organize" + 0.055*"times" + 0.055*"hours"')
# (2, '0.053*"office" + 0.053*"hours" + 0.053*"clear" + 0.053*"things" + 0.053*"helpful"')
# (3, '0.094*"clear" + 0.094*"helpful" + 0.094*"office" + 0.094*"knowledgeable" + 0.094*"hours"')
# (4, '0.162*"office" + 0.111*"hours" + 0.111*"teacher" + 0.061*"pool" + 0.061*"class"')
# live session
# (0, '0.136*"discussion" + 0.072*"really" + 0.070*"tough" + 0.038*"sessions" + 0.038*"class"')
# (1, '0.039*"session" + 0.039*"going" + 0.039*"unclear" + 0.039*"technical" + 0.039*"clear"')
# (2, '0.047*"sleep" + 0.046*"means" + 0.046*"thought" + 0.046*"things" + 0.045*"though"')
# (3, '0.071*"session" + 0.070*"discussion" + 0.039*"things" + 0.039*"class" + 0.039*"really"')
# (4, '0.112*"class" + 0.061*"discussion" + 0.061*"annoying" + 0.061*"dominate" + 0.061*"overall"')
# course material
# (0, '0.031*"module" + 0.017*"however" + 0.017*"understanding" + 0.017*"async" + 0.017*"aspect"')
# (1, '0.027*"class" + 0.027*"concept" + 0.027*"would" + 0.027*"reading" + 0.015*"level"')
# (2, '0.022*"definitely" + 0.022*"things" + 0.022*"pretty" + 0.022*"actually" + 0.022*"finally"')
# (3, '0.027*"could" + 0.027*"specific" + 0.027*"class" + 0.019*"really" + 0.019*"instruction"')
# (4, '0.033*"material" + 0.033*"class" + 0.033*"really" + 0.023*"apply" + 0.023*"enjoy"')

# %%
dictionary = load_from_text('dictionary_feedback.gensim')

ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=NUM_PASSES)
ldamodel_filename = 'topic_models/feedback_model%st_%sp.gensim' % (str(NUM_TOPICS), str(NUM_PASSES))
ldamodel.save(ldamodel_filename)
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.028*"async" + 0.026*"really" + 0.018*"discussion" + 0.017*"class"')
# (1, '0.026*"really" + 0.022*"assignment" + 0.021*"async" + 0.020*"class"')
# (2, '0.033*"async" + 0.016*"class" + 0.013*"material" + 0.012*"session"')
# (3, '0.038*"class" + 0.026*"really" + 0.014*"question" + 0.012*"great"')
# (4, '0.036*"assignment" + 0.028*"feedback" + 0.021*"might" + 0.016*"grade"')

# %%
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=10)
ldamodel.save('feedback_model5t_10p_4w.gensim')
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.016*"material" + 0.016*"question" + 0.014*"slack" + 0.013*"might"')
# (1, '0.044*"class" + 0.025*"async" + 0.018*"discussion" + 0.016*"really"')
# (2, '0.030*"async" + 0.027*"really" + 0.026*"assignment" + 0.020*"class"')
# (3, '0.027*"really" + 0.017*"async" + 0.014*"class" + 0.013*"great"')
# (4, '0.045*"feedback" + 0.030*"semester" + 0.024*"grade" + 0.016*"assignment"')

# %%
NUM_TOPICS = 3
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=20)
ldamodel.save('feedback_model3t_20p_4w.gensim')
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.032*"class" + 0.029*"async" + 0.022*"session" + 0.013*"feedback"')
# (1, '0.016*"async" + 0.015*"assignment" + 0.014*"material" + 0.014*"really"')
# (2, '0.026*"really" + 0.020*"assignment" + 0.018*"feedback" + 0.015*"grade"')

# %%
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=20)
#ldamodel.save('feedback_model4t_20p_6w.gensim')
topics = ldamodel.print_topics(num_words=5)
for topic in topics:
    print(topic)
# Out:
# (0, '0.017*"really" + 0.015*"would" + 0.012*"question" + 0.012*"interest" + 0.009*"might"')
# (1, '0.049*"class" + 0.032*"async" + 0.027*"really" + 0.017*"session" + 0.014*"material"')
# (2, '0.019*"async" + 0.015*"question" + 0.013*"quality" + 0.013*"really" + 0.010*"pretty"')
# (3, '0.027*"class" + 0.026*"assignment" + 0.018*"video" + 0.012*"async" + 0.012*"really"')
# (4, '0.041*"feedback" + 0.033*"assignment" + 0.024*"grade" + 0.018*"semester" + 0.016*"instructor"')
