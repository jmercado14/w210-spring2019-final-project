# %%
import numpy as np
import pandas as pd
import nltk
# nltk.download('punkt')
# nltk.download('stopwords')
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
# nltk.download('wordnet')
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer

import re
import networkx as nx
from sklearn.metrics.pairwise import cosine_similarity

import spacy
spacy.load('en')
from spacy.lang.en import English
parser = English()
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

import gensim
from gensim import corpora
from gensim.summarization.summarizer import summarize
import pickle

# %%
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)

en_stop = set(nltk.corpus.stopwords.words('english'))

def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %% [markdown]
# ### Load training data

# %%
# load file
training_feedback = pd.read_csv('training_data/feedback_data_for_training.csv')

# %%
training_feedback
# Out:
#              source                                      feedback_text  \
# 0    team_generated  i have no idea how i’m doing so far. we’ve tur...
# 1    team_generated  i’d ask for more time from the TAs, or try to ...
# 2    team_generated  the way that they encourage lots of class disc...
# 3    team_generated  async is going pretty well, but not super appl...
# 4    team_generated    abe lincoln is the best professor i’ve ever had
# 5    team_generated                                        tech is bad
# 6    team_generated                                this is a great bot
# 7    team_generated  the breakout sessions were very engaging, and ...
# 8    team_generated  one person dominated the full-class discussion...
# 9    team_generated  they’re fine. problem sets are really helpful,...
# 10   team_generated  async was okay. it felt superfluous though. it...
# 11   team_generated  i feel like we could use an extra TA - it woul...
# 12   team_generated  live session was good! lots of lively discussi...
# 13   team_generated  async was pretty repetitive. it felt like a lo...
# 14   team_generated  still haven’t gotten any feedback on assignmen...
# 15   team_generated  class is going well! i feel like i’m understan...
# 16   team_generated  it was good - it ran half an hour over, which ...
# 17   team_generated  it was good - it ran half an hour over, which ...
# 18   team_generated  async felt a little long this week, it didn’t ...
# 19   team_generated  the problem sets have been really difficult. i...
# 20   team_generated  live sessions have been running late recently,...
# 21   team_generated  i  thought the discussion was really productiv...
# 22   team_generated  it was okay. i feel like the async for the las...
# 23   team_generated  didn’t have any assignments this week, so all ...
# 24   team_generated  live session hasn’t really had anything to do ...
# 25   team_generated  haven't gotten any feedback on assignments yet...
# 26   team_generated            live session feels like a waste of time
# 27   team_generated  live session runs forever, feels superfluous, ...
# 28   team_generated  async and live session have nothing to do with...
# 29   team_generated  live session ran over time this week. it alway...
# ..              ...                                                ...
# 207      class_recs  I prefer a collection of single purpose tools ...
# 208      class_recs  So I don't ever have to have another gd meetin...
# 209      class_recs  She and the co-professor are still figuring it...
# 210      class_recs  Biggest challenge for me was installing Jupyte...
# 211      class_recs  Most of all (and he's been doing this less sin...
# 212      class_recs  Totally agree on the need for zoom/full screen...
# 213      class_recs  No subtitles, and images that are too small to...
# 214      class_recs  For example, when I was professoring, students...
# 215      class_recs  I would add that you should be prepared to pro...
# 216      class_recs  No particular synergy other classes except tha...
# 217      class_recs  He adds supplemental material to the live lect...
# 218      class_recs  The teaching staff does a wonderful job of foc...
# 219      class_recs  instructors were pretty good about walking thr...
# 220      class_recs  the instruction team has to do a TON of prepar...
# 221      class_recs  The materials are VERY synced up between diffe...
# 222      class_recs  we're doing DL in near end of the semester. Bu...
# 223      class_recs                    live sessions are very hands on
# 224      class_recs  my instructors for 261 weren't very good and h...
# 225      class_recs  t's a lot of Spark functional programming but ...
# 226      class_recs  The live sessions were more lectures than disc...
# 227      class_recs  he has a really good approach to working throu...
# 228      class_recs  the async is all theory/intuition (nothing abo...
# 229      class_recs  if you don’t have a mac you might want to inve...
# 230      class_recs  he's a good teacher, as long as you want pract...
# 231      class_recs  While we could get into interesting tangents a...
# 232      class_recs  working through python assignments and the fin...
# 233      class_recs  We have feedback as a class early that lecturi...
# 234      class_recs  Implementation with code is left to the proble...
# 235      class_recs  I was pretty angry about the async quality las...
# 236      class_recs  The assignments can be nasty (but very worthwh...
#
#             topic                       sub_topic Unnamed: 4
# 0     assignments                 slow turnaround        NaN
# 1     assignments                 slow turnaround        NaN
# 2    live session                 good discussion        NaN
# 3           async  disconnected from live session        NaN
# 4     instructors                             NaN        NaN
# 5      technology                        negative        NaN
# 6      technology                        positive        NaN
# 7    live session                 good discussion        NaN
# 8    live session                      unbalanced        NaN
# 9     assignments                 slow turnaround        NaN
# 10          async  disconnected from live session        NaN
# 11    assignments                 slow turnaround        NaN
# 12   live session                 good discussion        NaN
# 13          async                     low quality        NaN
# 14    assignments                 slow turnaround        NaN
# 15    assignments                 slow turnaround        NaN
# 16   live session                 good discussion        NaN
# 17   live session            not keeping schedule        NaN
# 18          async  disconnected from live session        NaN
# 19    assignments                   too difficult        NaN
# 20   live session            not keeping schedule        NaN
# 21   live session                      unbalanced        NaN
# 22          async  disconnected from live session        NaN
# 23    assignments                             NaN        NaN
# 24          async  disconnected from live session        NaN
# 25    assignments                 slow turnaround        NaN
# 26   live session                     not helpful        NaN
# 27   live session                     not helpful        NaN
# 28          async  disconnected from live session        NaN
# 29   live session            not keeping schedule        NaN
# ..            ...                             ...        ...
# 207    technology                             NaN        NaN
# 208    technology                             NaN        NaN
# 209    technology                             NaN        NaN
# 210    technology                             NaN        NaN
# 211    technology                             NaN        NaN
# 212    technology                             NaN        NaN
# 213    technology                             NaN        NaN
# 214    technology                             NaN        NaN
# 215    technology                             NaN        NaN
# 216    technology                             NaN        NaN
# 217  live session                             NaN        NaN
# 218   instructors                             NaN        NaN
# 219  live session                             NaN        NaN
# 220  live session                             NaN        NaN
# 221  live session                             NaN        NaN
# 222    technology                             NaN        NaN
# 223  live session                             NaN        NaN
# 224  live session                             NaN        NaN
# 225    technology                             NaN        NaN
# 226  live session                             NaN        NaN
# 227  live session                             NaN        NaN
# 228         async                             NaN        NaN
# 229    technology                             NaN        NaN
# 230  live session                             NaN        NaN
# 231  live session                             NaN        NaN
# 232   assignments                             NaN        NaN
# 233  live session                             NaN        NaN
# 234   assignments                             NaN        NaN
# 235         async                             NaN        NaN
# 236   assignments                             NaN        NaN
#
# [237 rows x 5 columns]

# %%
topics = set(training_feedback.topic)
topics
# Out:
# {'assignments',
#  'async',
#  'instructors',
#  'live session',
#  'miscellaneous',
#  'technology'}

# %% [markdown]
# ### Create topic models

# %%
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

training_subset = training_feedback[(training_feedback['topic'] != 'misc')]

training_text = training_subset.feedback_text
training_targets = np.array(training_subset.topic)
training_text_clean = []
for text in training_text:
    training_text_clean.append(" ".join(prepare_text_for_lda(text)))  
training_text_clean = np.reshape(training_text_clean,(-1,))

# %%
training_targets
# Out:
# array(['assignments', 'assignments', 'live session', 'async',
#        'instructors', 'technology', 'technology', 'live session',
#        'live session', 'assignments', 'async', 'assignments',
#        'live session', 'async', 'assignments', 'assignments',
#        'live session', 'live session', 'async', 'assignments',
#        'live session', 'live session', 'async', 'assignments', 'async',
#        'assignments', 'live session', 'live session', 'async',
#        'live session', 'async', 'technology', 'async', 'technology',
#        'technology', 'technology', 'async', 'async', 'technology',
#        'async', 'async', 'async', 'async', 'instructors', 'instructors',
#        'assignments', 'assignments', 'technology', 'miscellaneous',
#        'miscellaneous', 'async', 'miscellaneous', 'async', 'live session',
#        'assignments', 'assignments', 'assignments', 'assignments',
#        'assignments', 'assignments', 'assignments', 'assignments',
#        'miscellaneous', 'miscellaneous', 'assignments', 'assignments',
#        'assignments', 'technology', 'technology', 'assignments',
#        'assignments', 'technology', 'async', 'technology', 'assignments',
#        'assignments', 'instructors', 'miscellaneous', 'assignments',
#        'assignments', 'miscellaneous', 'assignments', 'instructors',
#        'async', 'assignments', 'instructors', 'async', 'instructors',
#        'assignments', 'async', 'assignments', 'async', 'live session',
#        'assignments', 'live session', 'miscellaneous', 'async',
#        'assignments', 'assignments', 'instructors', 'async', 'async',
#        'instructors', 'assignments', 'instructors', 'live session',
#        'live session', 'instructors', 'async', 'instructors',
#        'assignments', 'instructors', 'instructors', 'instructors',
#        'instructors', 'instructors', 'instructors', 'miscellaneous',
#        'miscellaneous', 'instructors', 'async', 'instructors',
#        'instructors', 'instructors', 'live session', 'assignments',
#        'instructors', 'miscellaneous', 'instructors', 'async',
#        'instructors', 'instructors', 'assignments', 'assignments',
#        'instructors', 'instructors', 'miscellaneous', 'instructors',
#        'instructors', 'instructors', 'async', 'instructors',
#        'instructors', 'miscellaneous', 'live session', 'assignments',
#        'live session', 'assignments', 'assignments', 'assignments',
#        'assignments', 'assignments', 'assignments', 'assignments',
#        'assignments', 'assignments', 'technology', 'instructors',
#        'instructors', 'miscellaneous', 'assignments', 'miscellaneous',
#        'async', 'async', 'assignments', 'instructors', 'instructors',
#        'miscellaneous', 'assignments', 'instructors', 'instructors',
#        'instructors', 'instructors', 'instructors', 'instructors',
#        'assignments', 'instructors', 'instructors', 'instructors',
#        'instructors', 'async', 'assignments', 'instructors',
#        'instructors', 'assignments', 'assignments', 'instructors',
#        'assignments', 'instructors', 'assignments', 'async',
#        'miscellaneous', 'instructors', 'instructors', 'technology',
#        'assignments', 'assignments', 'instructors', 'assignments',
#        'technology', 'technology', 'technology', 'technology', 'async',
#        'technology', 'technology', 'technology', 'technology',
#        'technology', 'technology', 'technology', 'technology',
#        'technology', 'technology', 'technology', 'technology',
#        'technology', 'live session', 'instructors', 'live session',
#        'live session', 'live session', 'technology', 'live session',
#        'live session', 'technology', 'live session', 'live session',
#        'async', 'technology', 'live session', 'live session',
#        'assignments', 'live session', 'assignments', 'async',
#        'assignments'], dtype=object)

# %%
#train_x, test_x, train_y, test_y = model_selection.train_test_split(training_feedback['feedback_text'], 
train_x, test_x, train_y, test_y = model_selection.train_test_split(training_text_clean, 
                                                                      training_targets)

# %%
train_x.shape, train_y.shape, test_x.shape, test_y.shape
# Out:
# ((177,), (177,), (60,), (60,))

# %%
#train_x = train_x.reshape(-1, 1)
#test_x = test_x.reshape(-1, 1)
#train_y = train_y.reshape(-1, 1)
#test_y = test_y.reshape(-1, 1)

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()

train_x_counts = count_vect.fit_transform(train_x)

from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
train_x_tfidf = tfidf_transformer.fit_transform(train_x_counts)

from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(train_x_tfidf, train_y)

predicted = clf.predict(tfidf_transformer.transform(count_vect.transform(test_x)))
np.mean(predicted == test_y)
# Out:
# 0.4166666666666667

# %%
from sklearn.model_selection import GridSearchCV
parameters = {
    'alpha': (1, 0.1, 0.01, 0.001, 0.0001, 0.00001)  
             }

clf = MultinomialNB()
gs_clf = GridSearchCV(estimator=clf, param_grid=parameters, n_jobs=-1, iid=True)

gs_clf = gs_clf.fit(train_x_counts, train_y)

gs_clf.best_score_
gs_clf.best_params_

print("Optimal alpha = {}; best MNB score = {:.3}".format(gs_clf.best_params_, gs_clf.best_score_))
# Out:
# /Users/jenniferpodracky/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# Optimal alpha = {'alpha': 1}; best MNB score = 0.503

# %%
from sklearn.model_selection import GridSearchCV
parameters = {
    'alpha': (1, 0.1, 0.01, 0.001, 0.0001, 0.00001)  
             }

clf = MultinomialNB()
gs_clf = GridSearchCV(estimator=clf, param_grid=parameters, n_jobs=-1, iid=True)

gs_clf = gs_clf.fit(train_x_tfidf, train_y)

gs_clf.best_score_
gs_clf.best_params_

print("Optimal alpha = {}; best MNB score = {:.3}".format(gs_clf.best_params_, gs_clf.best_score_))
# Out:
# Optimal alpha = {'alpha': 0.1}; best MNB score = 0.525
# /Users/jenniferpodracky/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
from sklearn.pipeline import Pipeline
text_clf = Pipeline([
     ('vect', CountVectorizer()),
     ('tfidf', TfidfTransformer()),
     ('clf', MultinomialNB()),
 ])

# text_clf.fit(train_x, train_y)  
# predicted = text_clf.predict(test_x)
# np.mean(predicted == test_y) 

parameters = {
     'vect__ngram_range': [(1, 1), (1, 2), (1,3)],
     'tfidf__use_idf': (True, False),
     'clf__alpha': (1, 0.1, 0.01, 0.001, 0.0001, 0.00001) ,
}

gs_clf = GridSearchCV(text_clf, parameters, cv=5, iid=False, n_jobs=-1)
gs_clf = gs_clf.fit(train_x, train_y)
print(gs_clf.best_score_)
print(gs_clf.best_params_)
# Out:
# 0.5309516238928004
# {'clf__alpha': 0.1, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 1)}

# %%
model_filename = 'topic_models/full_topic_model.sav'
pickle.dump(gs_clf, open(model_filename, 'wb'))

# %% [markdown]
# ### Create subtopic models, by topic

# %%
def generate_dictionary_corpus(data_id, full_text):
    # going to take 5-10 minutes
    
    feedback_tokenized = []
    
    for t in full_text:
        tokens = prepare_text_for_lda(str(t))
        feedback_tokenized.append(tokens)
        
    dictionary = corpora.Dictionary(feedback_tokenized)
    dictionary_filename = "topic_dictionaries/%s_dictionary_feedback.gensim" % (data_id)
    corpus = [dictionary.doc2bow(text) for text in feedback_tokenized]
    corpus_filename = "topic_corpi/%s_corpus_feedback.pkl" % (data_id)
    
    pickle.dump(corpus, open(corpus_filename, 'wb'))
    dictionary.save(dictionary_filename)
    return dictionary, corpus

def load_dictionary_corpus(data_id):
    dictionary_filename = "topic_dictionaries/%s_dictionary_feedback.gensim" % (data_id)
    dictionary = corpora.Dictionary.load(dictionary_filename)
    corpus_filename = "topic_corpi/%s_corpus_feedback.pkl" % (data_id)
    with open(corpus_filename, 'rb') as f:
        corpus = pickle.load(f)
    if (len(dictionary) == 0):
        return
    return dictionary, corpus
    
def generate_lda(data_id, corpus, dictionary, num_topics, num_passes, num_words):
    # runtime will depend on number of passes
    ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = num_topics, id2word=dictionary, passes=num_passes)
    ldamodel_filename = 'topic_models/%s_model%st_%sp.gensim' % (data_id, str(num_topics), str(num_passes))
    ldamodel.save(ldamodel_filename)
    
    sub_topics = ldamodel.print_topics(num_words=num_words)
    for sub_topic in sub_topics:
        print(sub_topic)
        
    return ldamodel

# %%
for topic in topics: 
    print ("Processing", topic)
    topic_subset = training_feedback[training_feedback.topic==topic]
    topic_text = topic_subset.feedback_text
    
    dictionary, corpus = generate_dictionary_corpus(topic, topic_text)
# Out:
# Processing miscellaneous
# Processing assignments
# Processing technology
# Processing async
# Processing instructors
# Processing live session

# %%
for topic in topics:
    print ("Processing", topic)
    topic_subset = training_feedback[training_feedback.topic==topic]
    topic_text = topic_subset.feedback_text
    # print(text)
    
    chats_tokenized = []
    
    for t in topic_text:
        tokens = prepare_text_for_lda(t)
        chats_tokenized.append(tokens)
        
    dictionary = corpora.Dictionary(chats_tokenized)
    dictionary_filename = "topic_dictionaries/%s_dictionary_feedback.gensim" % (str(topic))
    corpus = [dictionary.doc2bow(text) for text in chats_tokenized]
    corpus_filename = "topic_corpi/%s_corpus_feedback.pkl" % (str(topic))
    

    pickle.dump(corpus, open(corpus_filename, 'wb'))
    dictionary.save(dictionary_filename)
# Out:
# Processing miscellaneous
# Processing assignments
# Processing technology
# Processing async
# Processing instructors
# Processing live session

# %%
NUM_TOPICS = 3
NUM_PASSES = 15
NUM_WORDS = 5

for topic in topics:
    print(topic)
    dictionary, corpus = load_dictionary_corpus(topic)
    generate_lda(topic, corpus, dictionary, NUM_TOPICS, NUM_PASSES, NUM_WORDS)
# Out:
# miscellaneous
# (0, '0.050*"reading" + 0.035*"definitely" + 0.020*"class" + 0.020*"longer" + 0.020*"portion"')
# (1, '0.027*"assignment" + 0.027*"material" + 0.027*"still" + 0.027*"really" + 0.027*"system"')
# (2, '0.041*"light" + 0.029*"assume" + 0.029*"workload" + 0.029*"pretty" + 0.029*"anything"')
# assignments
# (0, '0.027*"assignment" + 0.020*"feedback" + 0.019*"project" + 0.016*"reading" + 0.013*"class"')
# (1, '0.036*"feedback" + 0.035*"assignment" + 0.029*"grade" + 0.018*"instructor" + 0.015*"semester"')
# (2, '0.048*"assignment" + 0.031*"feedback" + 0.030*"grade" + 0.016*"really" + 0.014*"get"')
# technology
# (0, '0.016*"question" + 0.016*"great" + 0.011*"reason" + 0.011*"better" + 0.011*"success"')
# (1, '0.023*"mobile" + 0.017*"quality" + 0.017*"stuff" + 0.017*"except" + 0.012*"laptop"')
# (2, '0.024*"class" + 0.020*"issue" + 0.017*"video" + 0.017*"would" + 0.017*"could"')
# async
# (0, '0.028*"async" + 0.020*"video" + 0.020*"class" + 0.020*"found" + 0.020*"design"')
# (1, '0.085*"async" + 0.021*"pretty" + 0.021*"quality" + 0.017*"textbook" + 0.017*"quiz"')
# (2, '0.049*"really" + 0.037*"async" + 0.032*"class" + 0.026*"anything" + 0.026*"session"')
# instructors
# (0, '0.029*"class" + 0.025*"slack" + 0.013*"really" + 0.012*"instructor" + 0.012*"material"')
# (1, '0.022*"class" + 0.019*"explain" + 0.018*"really" + 0.017*"office" + 0.014*"hours"')
# (2, '0.035*"class" + 0.014*"would" + 0.014*"people" + 0.010*"working" + 0.010*"sessions"')
# live session
# (0, '0.035*"session" + 0.035*"discussion" + 0.034*"class" + 0.024*"really" + 0.014*"clear"')
# (1, '0.048*"sessions" + 0.040*"discussion" + 0.037*"class" + 0.027*"could" + 0.022*"really"')
# (2, '0.031*"always" + 0.026*"apply" + 0.025*"session" + 0.018*"learn" + 0.018*"aspect"')

# %%
NUM_TOPICS = 3
NUM_PASSES = 15
NUM_WORDS = 5

for topic in topics:
    print(topic)
    dictionary, corpus = load_dictionary_corpus(topic)
    generate_lda(topic, corpus, dictionary, NUM_TOPICS, NUM_PASSES, NUM_WORDS)
# Out:
# miscellaneous
# (0, '0.032*"light" + 0.032*"really" + 0.022*"could" + 0.022*"anything" + 0.022*"assume"')
# (1, '0.048*"class" + 0.034*"system" + 0.034*"impossible" + 0.019*"still" + 0.019*"depend"')
# (2, '0.040*"reading" + 0.039*"definitely" + 0.022*"longer" + 0.022*"portion" + 0.022*"series"')
# assignments
# (0, '0.032*"feedback" + 0.023*"grade" + 0.023*"project" + 0.022*"might" + 0.021*"instructor"')
# (1, '0.025*"assignment" + 0.025*"really" + 0.022*"problem" + 0.019*"material" + 0.017*"grade"')
# (2, '0.061*"assignment" + 0.043*"feedback" + 0.017*"grade" + 0.012*"class" + 0.012*"spend"')
# technology
# (0, '0.020*"mobile" + 0.015*"laptop" + 0.015*"except" + 0.011*"great" + 0.010*"question"')
# (1, '0.026*"video" + 0.016*"specific" + 0.016*"quality" + 0.016*"great" + 0.011*"mobile"')
# (2, '0.023*"class" + 0.020*"issue" + 0.015*"would" + 0.015*"instructor" + 0.015*"session"')
# async
# (0, '0.045*"async" + 0.039*"class" + 0.034*"session" + 0.027*"discussion" + 0.021*"really"')
# (1, '0.053*"async" + 0.028*"think" + 0.021*"quiz" + 0.021*"really" + 0.021*"exercise"')
# (2, '0.070*"async" + 0.024*"quality" + 0.024*"really" + 0.020*"reading" + 0.020*"video"')
# instructors
# (0, '0.023*"really" + 0.019*"would" + 0.019*"class" + 0.019*"explain" + 0.012*"course"')
# (1, '0.033*"class" + 0.015*"material" + 0.014*"office" + 0.012*"slack" + 0.012*"question"')
# (2, '0.029*"class" + 0.017*"people" + 0.013*"instructor" + 0.013*"great" + 0.009*"student"')
# live session
# (0, '0.028*"session" + 0.028*"discussion" + 0.022*"sessions" + 0.017*"could" + 0.017*"challenge"')
# (1, '0.040*"class" + 0.040*"discussion" + 0.031*"sessions" + 0.030*"really" + 0.030*"sync"')
# (2, '0.028*"sessions" + 0.028*"class" + 0.019*"session" + 0.019*"things" + 0.019*"instructor"')

# %%
NUM_TOPICS = 3
NUM_PASSES = 25
NUM_WORDS = 3

for topic in topics:
    print(topic)
    dictionary, corpus = load_dictionary_corpus(topic)
    generate_lda(topic, corpus, dictionary, NUM_TOPICS, NUM_PASSES, NUM_WORDS)
# Out:
# miscellaneous
# (0, '0.054*"class" + 0.036*"reading" + 0.036*"assignment"')
# (1, '0.041*"light" + 0.041*"really" + 0.028*"speed"')
# (2, '0.027*"system" + 0.027*"speaker" + 0.016*"around"')
# assignments
# (0, '0.022*"grade" + 0.022*"quite" + 0.021*"problem"')
# (1, '0.048*"feedback" + 0.029*"assignment" + 0.023*"grade"')
# (2, '0.051*"assignment" + 0.026*"feedback" + 0.022*"project"')
# technology
# (0, '0.023*"issue" + 0.014*"student" + 0.014*"record"')
# (1, '0.030*"class" + 0.018*"watch" + 0.013*"video"')
# (2, '0.018*"mobile" + 0.018*"great" + 0.014*"would"')
# async
# (0, '0.037*"class" + 0.029*"reading" + 0.029*"discussion"')
# (1, '0.023*"async" + 0.021*"video" + 0.021*"watch"')
# (2, '0.091*"async" + 0.030*"session" + 0.027*"really"')
# instructors
# (0, '0.017*"slack" + 0.013*"instructor" + 0.013*"student"')
# (1, '0.018*"class" + 0.014*"sessions" + 0.014*"focus"')
# (2, '0.042*"class" + 0.020*"really" + 0.015*"office"')
# live session
# (0, '0.035*"sessions" + 0.034*"sync" + 0.024*"material"')
# (1, '0.041*"discussion" + 0.033*"session" + 0.028*"really"')
# (2, '0.044*"class" + 0.034*"sessions" + 0.023*"understand"')

# %%
NUM_TOPICS = 3
NUM_PASSES = 25
NUM_WORDS = 2

for topic in topics:
    print(topic)
    dictionary, corpus = load_dictionary_corpus(topic)
    generate_lda(topic, corpus, dictionary, NUM_TOPICS, NUM_PASSES, NUM_WORDS)
# Out:
# miscellaneous
# (0, '0.053*"really" + 0.037*"reading"')
# (1, '0.034*"system" + 0.019*"still"')
# (2, '0.043*"class" + 0.023*"material"')
# assignments
# (0, '0.044*"assignment" + 0.032*"grade"')
# (1, '0.030*"assignment" + 0.026*"reading"')
# (2, '0.043*"feedback" + 0.033*"assignment"')
# technology
# (0, '0.022*"class" + 0.022*"video"')
# (1, '0.036*"issue" + 0.013*"quality"')
# (2, '0.018*"except" + 0.018*"laptop"')
# async
# (0, '0.056*"async" + 0.042*"class"')
# (1, '0.086*"async" + 0.036*"really"')
# (2, '0.032*"found" + 0.032*"actually"')
# instructors
# (0, '0.025*"class" + 0.013*"people"')
# (1, '0.021*"instructor" + 0.021*"office"')
# (2, '0.041*"class" + 0.016*"explain"')
# live session
# (0, '0.040*"discussion" + 0.033*"session"')
# (1, '0.040*"sessions" + 0.034*"class"')
# (2, '0.032*"discussion" + 0.025*"really"')

# %% [markdown]
# ### Create subtopic models, separate from topic

# %%
topic_subset = training_feedback[training_feedback.topic==topic]
topic_text = topic_subset.feedback_text
    
dictionary, corpus = generate_dictionary_corpus(topic, topic_text)

# %%
topic_text = training_feedback.feedback_text

mids_dictionary, mids_corpus = generate_dictionary_corpus("mids", topic_text)

# %%
NUM_TOPICS = 10
NUM_PASSES = 15
NUM_WORDS = 2

# runtime will depend on number of passes
dictionary, corpus = load_dictionary_corpus(topic)
generate_lda("mids", corpus, dictionary, NUM_TOPICS, NUM_PASSES, NUM_WORDS)
# Out:
# (0, '0.051*"sometimes" + 0.027*"session"')
# (1, '0.061*"hands" + 0.061*"sessions"')
# (2, '0.052*"sleep" + 0.052*"means"')
# (3, '0.006*"concept" + 0.006*"lead"')
# (4, '0.040*"schedule" + 0.040*"apply"')
# (5, '0.048*"topic" + 0.032*"though"')
# (6, '0.055*"sync" + 0.055*"sessions"')
# (7, '0.047*"tough" + 0.047*"discussion"')
# (8, '0.071*"discussion" + 0.036*"enjoy"')
# (9, '0.117*"class" + 0.060*"discussion"')

# %%
NUM_TOPICS = 10
NUM_PASSES = 10
NUM_WORDS = 2

# runtime will depend on number of passes
dictionary, corpus = load_dictionary_corpus(topic)
generate_lda("mids", corpus, dictionary, NUM_TOPICS, NUM_PASSES, NUM_WORDS)
# Out:
# (0, '0.048*"always" + 0.025*"sometimes"')
# (1, '0.091*"class" + 0.047*"really"')
# (2, '0.068*"discussion" + 0.068*"session"')
# (3, '0.076*"sessions" + 0.076*"sync"')
# (4, '0.058*"apply" + 0.031*"enjoy"')
# (5, '0.085*"discussion" + 0.044*"feel"')
# (6, '0.006*"class" + 0.006*"question"')
# (7, '0.073*"sessions" + 0.038*"discussion"')
# (8, '0.040*"concept" + 0.022*"topic"')
# (9, '0.055*"session" + 0.037*"interest"')

# %%
from operator import itemgetter

def pred_sub_topic(text):
    
    # predict subtopic
    tokens = prepare_text_for_lda(str(text))
    # print(tokens)
    bow_tokens = dictionary.doc2bow(tokens)
    vector = ldamodel[bow_tokens]
    # print(vector)
    most_likely = max(vector,key=itemgetter(1))

    if (most_likely[1] < .11):
        # print("No best predictor")
        return None
    return most_likely[0]

# %%
for i in range(len(test_x)):
    print(pred_sub_topic(test_x[i]), ",", test_x[i])
# Out:
# 4 , engage
# 5 , going homework answer session help sometimes unclear technical clear provide confirmation specific formatting expression explanation rationale write assignment
# 7 , really struggle weekly assignment assignment twice instructor worry understand material
# None , need muuuuch slow
# 3 , teacher practical apply focus rather theory session active discussion format class
# 1 , making effective know stuff
# 6 , assignment nasty worthwhile instructions reading hint actual coding
# 2 , implementation problem project
# 0 , found decade article worthless personally found reading worthwhile still graduate level class something
# None , skeptical concern attitude towards student
# 6 , right pretty light workload point assume anything could grade
# None , subtitle image small laptop mobile except native browser slide
# 3 , instruction preparation session could otherwise spend asking interest challenge question topic
# 8 , reading realistically skimming
# 0 , expectation somewhat stifle student propensity question class great
# 1 , taste different practice coursework
# None , definitely fully bake
# 0 , think reading could tighten async short question awful
# 4 , session always coast means sleep
# 9 , big challenge installing jupyter notebook partial success latex success since seem dependency sequence installation steps
# 1 , prefer collection single purpose tool coming philosophy chain together working replace forum version control replace better different works better class standard would great html5 flash adobe connect accessibility problem
# 9 , async couple week anything actually talk session interest least struggle watching though since never actually review talking
# 7 , async superfluous though really anything talk session
# 2 , problem
# 3 , suggestion ischool speaker event accessible least recording student benefit great topic speaker
# 0 , found example async reading assignment incredibly useful background research
# 2 , great background class heavy notation abstract sometimes background decent fostering discussion serious helping people learn instructor opinion
# None , little
# 5 , although session interface restrict official recording sessions instructor reason student could something nvidia shadowplay record session computer
# 7 , assignment pretty trivial final project paper
# 0 , aware really attention participation coding exercise async
# 5 , clear engage give answer question
# None , difficult
# 9 , tough discussion
# 1 , consistently manage effectively know want valuable underappreciated skill
# 3 , think unacceptable different source truth frankly prefer leverage platform figure transition whatever would great build specific training technology software could series instructional video could specific website specific online resource found answer google
# 6 , spark functional programming surprisingly cluster
# 2 , provide example industry context right mixture banter engagement treat class grownup police folks working together
# 5 , think solid instructor explain material answer question effectively office hours
# 9 , class going understanding material finally though grade get grade backyet
# 8 , pretty straight forward generally generous grading first semester short amount outside class like style generally
# 5 , instructor super responsive
# 6 , might thing trip take forever figure computer week week quite tough
# 7 , problem intensive spending upwards hours assignment sustainable
# 0 , recommend instructor struggle communication session really knowledgeable write clearly speaking style barrier professor answer question still benefit strength without lecturer
# 0 , class screen share slack would serve purpose probably reliable counter would automatically archive class counter argument blood pressure actually watch archive class session
# 2 , grading coming receive feedback week2 presentation night presentation similarly grade certainly make learn
# 1 , feedback class early lecturing writing tablet effective would interactive actually discuss things asking question throughout allocate minutes class breakout sessions frustrate understand clock counting quickly
# None , program appear badly understaffed upcoming
# 0 , async class better asyncs
# 9 , async going pretty super applicable session discussion
# 1 , asyncs learning anything asyncs pretty useless
# 1 , really approach working proof class
# 7 , enjoy assignment unclear material async focus
# 9 , working professional field extra developing material pedagogy class times along line hash async catching recent article space student present cloud
# 9 , reading discussion fantastic project incredibly interest
# 7 , async pretty repetitive material cover multiple times session sleepy
# 6 , might invest people issue
# 0 , lecture really value class reading project async amaze
# 7 , async explanation interactivity integrate textbook

# %%
# kmeans clustering

NUM_TOPICS = 10
NUM_PASSES = 10
NUM_WORDS = 2


from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()

train_x_counts = count_vect.fit_transform(train_x)

from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
train_x_tfidf = tfidf_transformer.fit_transform(train_x_counts)

from sklearn.cluster import KMeans
km_model = KMeans(n_clusters=NUM_TOPICS, init='k-means++', max_iter=200, n_init=100)
km_model.fit(train_x_tfidf)

predicted = km_model.predict(tfidf_transformer.transform(count_vect.transform(test_x)))
#print(predicted)
#print(test_x)

for i in range(len(predicted)):
    print(predicted[i], ",", test_x[i])
# Out:
# 0 , engage
# 0 , going homework answer session help sometimes unclear technical clear provide confirmation specific formatting expression explanation rationale write assignment
# 0 , really struggle weekly assignment assignment twice instructor worry understand material
# 0 , need muuuuch slow
# 8 , teacher practical apply focus rather theory session active discussion format class
# 0 , making effective know stuff
# 1 , assignment nasty worthwhile instructions reading hint actual coding
# 3 , implementation problem project
# 1 , found decade article worthless personally found reading worthwhile still graduate level class something
# 2 , skeptical concern attitude towards student
# 3 , right pretty light workload point assume anything could grade
# 0 , subtitle image small laptop mobile except native browser slide
# 9 , instruction preparation session could otherwise spend asking interest challenge question topic
# 1 , reading realistically skimming
# 4 , expectation somewhat stifle student propensity question class great
# 0 , taste different practice coursework
# 1 , definitely fully bake
# 7 , think reading could tighten async short question awful
# 7 , session always coast means sleep
# 1 , big challenge installing jupyter notebook partial success latex success since seem dependency sequence installation steps
# 0 , prefer collection single purpose tool coming philosophy chain together working replace forum version control replace better different works better class standard would great html5 flash adobe connect accessibility problem
# 7 , async couple week anything actually talk session interest least struggle watching though since never actually review talking
# 7 , async superfluous though really anything talk session
# 3 , problem
# 4 , suggestion ischool speaker event accessible least recording student benefit great topic speaker
# 1 , found example async reading assignment incredibly useful background research
# 8 , great background class heavy notation abstract sometimes background decent fostering discussion serious helping people learn instructor opinion
# 0 , little
# 7 , although session interface restrict official recording sessions instructor reason student could something nvidia shadowplay record session computer
# 0 , assignment pretty trivial final project paper
# 7 , aware really attention participation coding exercise async
# 0 , clear engage give answer question
# 0 , difficult
# 6 , tough discussion
# 0 , consistently manage effectively know want valuable underappreciated skill
# 4 , think unacceptable different source truth frankly prefer leverage platform figure transition whatever would great build specific training technology software could series instructional video could specific website specific online resource found answer google
# 0 , spark functional programming surprisingly cluster
# 0 , provide example industry context right mixture banter engagement treat class grownup police folks working together
# 4 , think solid instructor explain material answer question effectively office hours
# 3 , class going understanding material finally though grade get grade backyet
# 3 , pretty straight forward generally generous grading first semester short amount outside class like style generally
# 2 , instructor super responsive
# 0 , might thing trip take forever figure computer week week quite tough
# 0 , problem intensive spending upwards hours assignment sustainable
# 7 , recommend instructor struggle communication session really knowledgeable write clearly speaking style barrier professor answer question still benefit strength without lecturer
# 8 , class screen share slack would serve purpose probably reliable counter would automatically archive class counter argument blood pressure actually watch archive class session
# 3 , grading coming receive feedback week2 presentation night presentation similarly grade certainly make learn
# 5 , feedback class early lecturing writing tablet effective would interactive actually discuss things asking question throughout allocate minutes class breakout sessions frustrate understand clock counting quickly
# 0 , program appear badly understaffed upcoming
# 8 , async class better asyncs
# 7 , async going pretty super applicable session discussion
# 0 , asyncs learning anything asyncs pretty useless
# 0 , really approach working proof class
# 0 , enjoy assignment unclear material async focus
# 0 , working professional field extra developing material pedagogy class times along line hash async catching recent article space student present cloud
# 1 , reading discussion fantastic project incredibly interest
# 7 , async pretty repetitive material cover multiple times session sleepy
# 2 , might invest people issue
# 1 , lecture really value class reading project async amaze
# 7 , async explanation interactivity integrate textbook

# %% [markdown]
# ### Generate topic summaries

# %%
for topic in topics:
    print ("Processing", topic)
    topic_subset = training_feedback[training_feedback.topic==topic]
    topic_text = topic_subset.feedback_text
    
    s = '. '
    text = s.join(topic_text)
    text = re.sub("\.+", ".", text)
    text = re.sub("\n", "", text)
    # print(text)
    print(summarize(text))
    print('\n')
# Out:
# Processing miscellaneous
# The week off for fall immersion seemed unexpected to both of my professors when it came to planning class material/projects/assignments.
# I’m finding w203 challenging re: speed/number of concepts to consume (I really want to internalize/grasp them but feel we’re moving at light speed).
# Good luck, you're gonna need it.
# There's a huge amount of reading just to understand what's going on
#
#
# Processing assignments
# we’ve turned in four assignments so far, but i haven’t received feedback on ANY of them.
# i’d ask for more time from the TAs, or try to bring  on some additional TAs so they can turn around assignments faster.
# problem sets are really helpful, but we haven’t gotten any feedback on them so far so i’m not sure how well i’m actually doing on these.
# i feel like we could use an extra TA - it would really help with the problem set feedback turnaround.
# still haven’t gotten any feedback on assignments so far, which is frustrating.
# they’re pretty straightforward, though, which is nice.we really need to start getting feedback on assignments we’ve turned in.
# i feel like i’m understanding the material finally, even though i’m not sure what my grade is yet because we haven’t gotten any grades backyet.
# haven't gotten any feedback on assignments yet.
# Are people frustrated with the amount of assignments they've had graded?
# I think this is particularly frustrating for us in our first semester - there should be extra emphasis on timely grading, as many of us are adjusting to being back in school after a while and it would be helpful to get more feedback in real time.
# I think my main comment is that so many of the major assignments are group that they we only get individual feedback on small homework pieces.
# There is discussion around making two end of semester deadlines for instructors, one for final grades, the other for final project feedback.
# Ideas for how to improve instructor feedback throughout the semester are still being evaluated, more to come when we hear more.
# grade turnaround time.
# i haven't gotten any feedback on any of my problems sets, and we're halfway through the semester.
# . And 207 is wide topic, the assignments are quite open ended, you can spend as much time tinkering with answer as you want.
# He can take a while to grade assignments, but he does provide detailed feedback.
# the problem sets have been way too time-intensive.
# this past assignment took twice as long as the instructor said it should, so i'm worried that i don't understand the material as well as i did.
# we spend so much time working on assignments, but we never review them in class.
# then we just get back a grade, with no additional feedback.
# He did get behind (2-3 weeks) for my section on grading all 3 labs, substantive feedback is also sparse, which does hinder with timely clarification of errors and omissions.
# . He sometimes takes quite a while (measured in weeks) to get your grades back to you after you submit an assignment, though.
# working through python assignments and the final project was the most rewarding part.
#
#
# Processing technology
# They make it harder to watch async on a mobile device (e.g. if I get a fee min to watch videos over lunch break, it's frustrating to hit one of those walls).
# Mobile experience with those isn't great, and the only time where I've seen it used in live sections was RDADA.
# The poor experience on mobile is my main concern here - being able to do async on the go is a key strategy for fitting MIDS into my life, and these are often a barrier.
# the experience of watching lectures on mobile is really.
# the videos lag, i can never get them to download all the way, and then the quality of the videos when fit to a tiny smartphone screen is not great.
# So, more than solving the actual homework problem, I am spending time trying to figure out logistical issues.
# So, more than solving the actual homework problem, I am spending time trying to figure out logistical issues.
# My only argument for the adobe connect platform is that one instructor who subbed one of my classes used some of the advanced features and it was great.
# The counter argument to that is my blood pressure any time I try to actually watch an archive class session in ISVC.
# One tool for forums, one tool for version control, one tool for web conf, etc -- where any one of those can be replaced with a better one, or just a different one that works better for that class.
# She and the co-professor are still figuring it out in terms of Zoom, ISVC, and access to the materials though.
# For example, when I was professoring, students would have to ask if they could record the class and get the instructor's permission before they did.
# In our experiences 48 gigs was need for the last question on hw5.
#
#
# Processing async
# async is going pretty well, but not super applicable to the live session discussion.
# it felt like a lot of the material was covered multiple times, and then AGAIN in the live session :sleepy:.
# async felt a little long this week, it didn’t seem super relevant to what we talked about in live session.
# i feel like the async for the last couple of weeks hasn’t had anything to do with what we’ve actually talked about in live session, but it has been interesting at least.
# live session hasn’t really had anything to do with the async lectures.
# i’m not really sure whether live session or async is more relevant to what we’re supposed to be taking out of this class :disappointed:.
# I really appreciated 209's Codepen exercises, and so far I think 241's integrated R Studio work is quite good, but the random quizzes or short response questions that predominate in async are terrible.
# I really appreciated 209's Codepen exercises, and so far I think 241's integrated R Studio work is quite good, but the random quizzes or short response questions that predominate in async are terrible.
# From my experience the async is about half good and half useless, and the textbook is subpar, so I think if you aren’t strong in math, you are going to need to commit a lot of time regardless of instructor.
# But the lectures aren’t really where the value is in that class: it’s in the readings and projects.
# Still not a graduate level class but I felt like I got something from those.
# the asyncs aren't very good for learning it on your own (if they're anything like 205's asyncs they'd be pretty useless).
#
#
# Processing instructors
# Downsides I would say the instructors are not as active on Slack (like W261 was awesome about that) so alot of questions are going unanswered (though other people usually work it out).
# The instructors are definitely good in their professional areas, but they appeared to stumble when I questioned them about something fundamental to CNN.
# He is really knowledgeable and writes very clearly but his speaking style was a barrier for me and, in 266, all the professors answer questions, so you can still benefit from his strengths without having him as your main lecturer.
# he was not particularly responsive to one of the classes about something, and I know it was escalated to MIDS admin people.
# He's also super accessible on Slack - rarely does it take more than a half hour to get a response from him, and he encourages his class to actively discuss the material on Slack, too.
# He explains the material well and he answers questions effectively during office hours.
# She always had good questions for the class to consider during the discussions.
# . I do feel like his high expectations somewhat stifle student's propensity to ask questions in class, which wasn't great.
# . he isn't great at finding alternative ways of explaining it if a student is having difficulty grasping the material.
# You will find yourself looking for alternate sources of lectures that do a better job of explaining the concepts, and the teacher is completely inaccessible outside of class.
# very good at making sync time effective and he knows his stuff.
# He does a decent job fostering discussion and does seem serious about helping people learn; he's not one of these "side-gig" instructors in my opinion.
# He doesn't spend much time talking code, which I'm mostly fine with because I prefer getting a solid conceptual understanding out of my sync sessions and can look into the math and code on my own.
# I liked that he'd bring additional examples (from his work and elsewhere) to class to complement the official material, too.
# really good, designed the whole course, hold office hours, explain concepts in great clarity & really responsive on piazza & mail.
# office hours many times, and he is very clear in explaining things, helpful, organized, and knowledgeable.
# He is very clear, engaging, gives good answers to questions, etc.
# . He explains things well, and has a really good approach to working through proofs "live" in class on an iPad. very engaging.
#
#
# Processing live session
# lots of lively discussion, which made class go by really fast, which was nice.
# it was good - it ran half an hour over, which was tough, but the discussion was fun so it didn’t seem like it took as long as it did.
# it was good - it ran half an hour over, which was tough, but the discussion was fun so it didn’t seem like it took as long as it did.
# live sessions have been running late recently, which has been really tough on my schedule (i’m in a different time zone, so going late means cutting into my sleep).
# The problem with this, is that the instruction team has to do a TON of preparation work, and lost live session time which could otherwise be spent on asking more interesting or challenging questions about the topic.
# the instruction team has to do a TON of preparation work, and lost live session time which could otherwise be spent on asking more interesting or challenging questions about the topic.
# The materials are VERY synced up between different live sessions up to the second last week -- the instructors always check in with each other to make sure that things are synced up.
# I like the active discussion format of his classes.
