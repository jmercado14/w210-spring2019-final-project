# %%
import numpy as np
import pandas as pd
import nltk
# nltk.download('punkt')
# nltk.download('stopwords')
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
# nltk.download('wordnet')
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer

import re
import networkx as nx
from sklearn.metrics.pairwise import cosine_similarity

import spacy
spacy.load('en')
from spacy.lang.en import English
parser = English()
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

import gensim
from gensim import corpora
import pickle

# %%
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)

en_stop = set(nltk.corpus.stopwords.words('english'))

def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
# load file
chats = pd.read_csv('student_feedback.csv')

# %%
chats
# Out:
#                                         feedback_text
# 0   i have no idea how i’m doing so far. we’ve tur...
# 1   i’d ask for more time from the TAs, or try to ...
# 2   the way that they encourage lots of class disc...
# 3   async is going pretty well, but not super appl...
# 4     abe lincoln is the best professor i’ve ever had
# 5                                         tech is bad
# 6                                 this is a great bot
# 7   pretty well, actually! i think i’m finally get...
# 8   the breakout sessions were very engaging, and ...
# 9   one person dominated the full-class discussion...
# 10  they’re fine. problem sets are really helpful,...
# 11  async was okay. it felt superfluous though. it...
# 12  i feel like we could use an extra TA - it woul...
# 13  class is… not going well. i’m feeling a little...
# 14  live session was good! lots of lively discussi...
# 15  async was pretty repetitive. it felt like a lo...
# 16  still haven’t gotten any feedback on assignmen...
# 17  class is going well! i feel like i’m understan...
# 18  it was good - it ran half an hour over, which ...
# 19  async felt a little long this week, it didn’t ...
# 20  the problem sets have been really difficult. i...
# 21  live sessions have been running late recently,...
# 22  class is going REALLY well right now. i’m real...
# 23  i  thought the discussion was really productiv...
# 24  it was okay. i feel like the async for the las...
# 25  didn’t have any assignments this week, so all ...
# 26  live session hasn’t really had anything to do ...
# 27  haven't gotten any feedback on assignments yet...
# 28            live session feels like a waste of time
# 29  live session runs forever, feels superfluous, ...
# ..                                                ...
# 41  I’d say the best features are the async videos...
# 42   Downsides I would say the instructors are not...
# 43  The instructors are definitely good in their p...
# 44  To top it, there is only one instructor who is...
# 45  Also, the instructors and TA's are super respo...
# 46  Lots of infrastructure issues just in the firs...
# 47  Right now it’s pretty light on workload, to th...
# 48  it's definitely a lot of reading + prep on you...
# 49  Lots of reading but realistically you can do a...
# 50  requires almost no work if you've ever used Li...
# 51  you can get by in 205 without reading anything...
# 52  Going over homework answers in w203 live sessi...
# 53  Are people frustrated with the amount of assig...
# 54  also has the grading coming in a bit late... M...
# 55  Also, the idea that I can only guess how each ...
# 56  without hw feedback, I’m left to learn by comp...
# 57  I think this is particularly frustrating for u...
# 58   The more fundamental question might be genera...
# 59  I would like to receive graded HW sooner becau...
# 60  I think my main comment is that so many of the...
# 61  One suggestion is to make more ischool speaker...
# 62  The week off for fall immersion seemed unexpec...
# 63   I actually need my grades to receive a reimbu...
# 64  It was certainly strange to have zero context ...
# 65   the organization of class material for both s...
# 66  However, they need to make sure those technolo...
# 67  I think its unacceptable to have so many diffe...
# 68  I just had assignments graded for 205 and 241....
# 69  Feedback on final projects: the administration...
# 70  The audio quality is pretty bad for some of th...
#
# [71 rows x 1 columns]

# %%
chats=chats.feedback_text

# %%
chats[1]
# Out:
# 'i’d ask for more time from the TAs, or try to bring  on some additional TAs so they can turn around assignments faster'

# %%
chats_tokenized = []
# preprocessing - WILL TAKE 30+ MINS

for i in range(len(chats)):
    tokens = prepare_text_for_lda(str(chats[i]))
    chats_tokenized.append(tokens)
    
chats_tokenized
# Out:
# [['turn',
#   'assignment',
#   'receive',
#   'feedback',
#   'super',
#   'frustrate',
#   'might',
#   'great',
#   'might',
#   'failing'],
#  ['bring', 'additional', 'around', 'assignment', 'fast'],
#  ['encourage', 'class', 'discussion', 'really'],
#  ['async', 'going', 'pretty', 'super', 'applicable', 'session', 'discussion'],
#  ['lincoln', 'professor'],
#  [],
#  ['great'],
#  ['pretty', 'actually', 'think', 'finally', 'getting', 'things'],
#  ['breakout',
#   'sessions',
#   'engage',
#   'really',
#   'enjoy',
#   'discussion',
#   'question'],
#  ['person', 'dominate', 'class', 'discussion', 'annoying', 'overall', 'class'],
#  ['problem', 'really', 'helpful', 'get', 'feedback', 'actually'],
#  ['async', 'superfluous', 'though', 'really', 'anything', 'talk', 'session'],
#  ['could',
#   'extra',
#   'would',
#   'really',
#   'problem',
#   'feedback',
#   'turnaround',
#   'things',
#   'going',
#   'though'],
#  ['class', 'going', 'feeling', 'little', 'material'],
#  ['session', 'lively', 'discussion', 'class', 'really'],
#  ['async',
#   'pretty',
#   'repetitive',
#   'material',
#   'cover',
#   'multiple',
#   'times',
#   'session',
#   'sleepy'],
#  ['still',
#   'get',
#   'feedback',
#   'assignment',
#   'frustrate',
#   'pretty',
#   'straightforward',
#   'though',
#   'really',
#   'start',
#   'getting',
#   'feedback',
#   'assignment',
#   'turn',
#   'halfway',
#   'semester',
#   'grade'],
#  ['class',
#   'going',
#   'understanding',
#   'material',
#   'finally',
#   'though',
#   'grade',
#   'get',
#   'grade',
#   'backyet'],
#  ['tough', 'discussion'],
#  ['async', 'little', 'super', 'relevant', 'talk', 'session'],
#  ['problem',
#   'really',
#   'difficult',
#   'learn',
#   'forever',
#   'working',
#   'student',
#   'totally'],
#  ['sessions',
#   'running',
#   'recently',
#   'really',
#   'tough',
#   'schedule',
#   'different',
#   'going',
#   'means',
#   'cutting',
#   'sleep',
#   'could',
#   'class',
#   'schedule',
#   'would',
#   'things',
#   'easy'],
#  ['class',
#   'going',
#   'really',
#   'right',
#   'really',
#   'enjoy',
#   'recent',
#   'material',
#   'starting',
#   'keeping',
#   'everyone',
#   'first'],
#  ['thought',
#   'discussion',
#   'really',
#   'productive',
#   'though',
#   'tense',
#   'point',
#   'first',
#   'reading',
#   'though',
#   'thought',
#   'things',
#   'normal'],
#  ['async',
#   'couple',
#   'week',
#   'anything',
#   'actually',
#   'talk',
#   'session',
#   'interest',
#   'least',
#   'struggle',
#   'watching',
#   'though',
#   'since',
#   'never',
#   'actually',
#   'review',
#   'talking'],
#  ['assignment'],
#  ['session',
#   'really',
#   'anything',
#   'async',
#   'lecture',
#   'really',
#   'whether',
#   'session',
#   'async',
#   'relevant',
#   'suppose',
#   'taking',
#   'class',
#   'disappoint'],
#  ['get', 'feedback', 'assignment', 'halfway', 'semester', 'unacceptable'],
#  ['session', 'feel', 'waste'],
#  ['session',
#   'forever',
#   'feel',
#   'superfluous',
#   'relate',
#   'things',
#   'review',
#   'async'],
#  ['async', 'session', 'nothing'],
#  ['session', 'always', 'coast', 'means', 'sleep'],
#  ['found',
#   'example',
#   'async',
#   'reading',
#   'assignment',
#   'incredibly',
#   'useful',
#   'background',
#   'research'],
#  ['hard',
#   'watch',
#   'async',
#   'mobile',
#   'device',
#   'watch',
#   'video',
#   'lunch',
#   'break',
#   'frustrate',
#   'wall',
#   'annoying',
#   'review',
#   'teacher',
#   'discuss',
#   'class',
#   'somebody',
#   'design',
#   'video',
#   'first',
#   'create',
#   'current',
#   'teacher'],
#  ['mobile',
#   'experience',
#   'great',
#   'section',
#   'rdada',
#   'minimal',
#   'necessarily',
#   'oppose',
#   'question',
#   'really',
#   'getting',
#   'extra',
#   'value'],
#  ['experience',
#   'mobile',
#   'concern',
#   'async',
#   'strategy',
#   'fitting',
#   'often',
#   'barrier'],
#  ['found',
#   'mobile',
#   'put_litter_in_its_place',
#   'though',
#   'complaint',
#   'matter',
#   'discussion',
#   'question',
#   'result',
#   'discussion',
#   'reason',
#   'exist'],
#  ['like',
#   'async',
#   'exercise',
#   'quiz',
#   'async',
#   'class',
#   'thought',
#   'effective',
#   'though'],
#  ['exercise', 'right', 'definitely', 'mobile', 'friendly'],
#  ['async', 'explanation', 'interactivity', 'integrate', 'textbook'],
#  ['really',
#   'appreciate',
#   'codepen',
#   'exercise',
#   'think',
#   'integrate',
#   'studio',
#   'quite',
#   'random',
#   'quiz',
#   'short',
#   'response',
#   'question',
#   'predominate',
#   'async',
#   'terrible'],
#  ['feature',
#   'async',
#   'video',
#   'excellent',
#   'quality',
#   'large',
#   'video',
#   'clear',
#   'speak'],
#  ['downside',
#   'would',
#   'instructor',
#   'active',
#   'slack',
#   'awesome',
#   'question',
#   'going',
#   'unanswered',
#   'though',
#   'people',
#   'usually',
#   'first',
#   'class',
#   'going',
#   'assignment',
#   'unclear',
#   'point',
#   'class',
#   'could',
#   'really',
#   'former',
#   'student'],
#  ['instructor',
#   'definitely',
#   'professional',
#   'area',
#   'appear',
#   'stumble',
#   'question',
#   'something',
#   'fundamental',
#   'feeling',
#   'aware',
#   'apply',
#   'works'],
#  ['instructor', 'responsive', 'slack', 'student', 'try', 'figure', 'issue'],
#  ['instructor', 'super', 'responsive'],
#  ['infrastructure',
#   'issue',
#   'first',
#   'week',
#   'continue',
#   'solving',
#   'actual',
#   'homework',
#   'problem',
#   'spending',
#   'try',
#   'figure',
#   'logistical',
#   'issue'],
#  ['right',
#   'pretty',
#   'light',
#   'workload',
#   'point',
#   'assume',
#   'anything',
#   'could',
#   'grade'],
#  ['definitely',
#   'reading',
#   'shame',
#   'series',
#   'portion',
#   'extend',
#   'longer',
#   'opinion'],
#  ['reading', 'realistically', 'skimming'],
#  ['require', 'almost', 'linux', 'command', 'spend', 'reading'],
#  ['without',
#   'reading',
#   'anything',
#   'might',
#   'actually',
#   'learn',
#   'something',
#   'chapter',
#   'actually',
#   'really',
#   'understand',
#   'works'],
#  ['going',
#   'homework',
#   'answer',
#   'session',
#   'help',
#   'sometimes',
#   'unclear',
#   'technical',
#   'clear',
#   'provide',
#   'confirmation',
#   'specific',
#   'formatting',
#   'expression',
#   'explanation',
#   'rationale',
#   'write',
#   'assignment'],
#  ['people',
#   'frustrate',
#   'amount',
#   'assignment',
#   'grade',
#   'certainly',
#   'feeling',
#   'instructor',
#   'might',
#   'overload'],
#  ['grading',
#   'coming',
#   'receive',
#   'feedback',
#   'week2',
#   'presentation',
#   'night',
#   'presentation',
#   'similarly',
#   'grade',
#   'certainly',
#   'make',
#   'learn'],
#  ['guess',
#   'course',
#   'going',
#   'uncomfortable',
#   'would',
#   'running',
#   'grade',
#   'influence'],
#  ['without',
#   'feedback',
#   'learn',
#   'comparing',
#   'answer',
#   'solution',
#   'worksheet',
#   'provide'],
#  ['think',
#   'particularly',
#   'frustrate',
#   'first',
#   'semester',
#   'extra',
#   'emphasis',
#   'timely',
#   'grading',
#   'adjust',
#   'school',
#   'would',
#   'helpful',
#   'feedback'],
#  ['fundamental',
#   'question',
#   'might',
#   'general',
#   'workload',
#   'instructor',
#   'given',
#   'teach',
#   'number',
#   'section',
#   'regular',
#   'case',
#   'might',
#   'interest',
#   'question',
#   'balance',
#   'broadly',
#   'translate',
#   'student',
#   'experience',
#   'holistically',
#   'might',
#   'cause',
#   'bump',
#   'email',
#   'responsiveness'],
#  ['would',
#   'receive',
#   'grade',
#   'sooner',
#   'corrective',
#   'action',
#   'requirement',
#   'degree'],
#  ['think',
#   'comment',
#   'major',
#   'assignment',
#   'group',
#   'individual',
#   'feedback',
#   'small',
#   'homework',
#   'piece',
#   'really',
#   'tonne',
#   'opportunity',
#   'creatitivity',
#   'depth'],
#  ['suggestion',
#   'ischool',
#   'speaker',
#   'event',
#   'accessible',
#   'least',
#   'recording',
#   'student',
#   'benefit',
#   'great',
#   'topic',
#   'speaker'],
#  ['immersion',
#   'seem',
#   'unexpected',
#   'professor',
#   'planning',
#   'class',
#   'material',
#   'project',
#   'assignment',
#   'still',
#   'expect',
#   'assignment',
#   'reading',
#   'async',
#   'material',
#   'actual',
#   'going',
#   'something'],
#  ['actually', 'grade', 'receive', 'reimbursement', 'company', 'others'],
#  ['certainly',
#   'strange',
#   'context',
#   'behind',
#   'grade',
#   'though',
#   'please',
#   'outcome',
#   'point',
#   'single',
#   'email',
#   'regard',
#   'assignment',
#   'grade',
#   'think',
#   'concern'],
#  ['organization',
#   'class',
#   'material',
#   'seem',
#   'quite',
#   'sloppy',
#   'recently',
#   'redo',
#   'understanding',
#   'apologetic',
#   'things',
#   'fully'],
#  ['however', 'technology', 'properly', 'another', 'syllabus'],
#  ['think',
#   'unacceptable',
#   'different',
#   'source',
#   'truth',
#   'frankly',
#   'prefer',
#   'leverage',
#   'platform',
#   'figure',
#   'transition',
#   'whatever',
#   'would',
#   'great',
#   'build',
#   'specific',
#   'training',
#   'technology',
#   'software',
#   'could',
#   'series',
#   'instructional',
#   'video',
#   'could',
#   'specific',
#   'website',
#   'specific',
#   'online',
#   'resource',
#   'found',
#   'answer',
#   'google'],
#  ['assignment',
#   'grade',
#   'within',
#   'week',
#   'submission',
#   'really',
#   'helpful',
#   'thorough',
#   'feedback',
#   'comment',
#   'question',
#   'grading',
#   'issue',
#   'want',
#   'mention',
#   'positive'],
#  ['feedback',
#   'final',
#   'project',
#   'administration',
#   'aware',
#   'instructor',
#   'feedback',
#   'throughout',
#   'semester',
#   'especially',
#   'final',
#   'project',
#   'discussion',
#   'around',
#   'making',
#   'semester',
#   'deadline',
#   'instructor',
#   'final',
#   'grade',
#   'final',
#   'project',
#   'feedback',
#   'idea',
#   'improve',
#   'instructor',
#   'feedback',
#   'throughout',
#   'semester',
#   'still',
#   'evaluate'],
#  ['audio',
#   'quality',
#   'pretty',
#   'async',
#   'stuff',
#   'usually',
#   'guest',
#   'speaker',
#   'issue',
#   'watching',
#   'section',
#   'focus',
#   'speaker',
#   'garble',
#   'background',
#   'noise',
#   'youtube',
#   'vlogger',
#   'better',
#   'audio',
#   'quality',
#   'interview',
#   'stuff']]

# %%
s = " "
clean_text = s.join(chats)
# clean_text
# Out:
# 'i have no idea how i’m doing so far. we’ve turned in four assignments so far, but i haven’t received feedback on ANY of them. it’s super frustrating. i might be doing great, but i might be failing. i’d ask for more time from the TAs, or try to bring  on some additional TAs so they can turn around assignments faster the way that they encourage lots of class discussion is really nice async is going pretty well, but not super applicable to the live session discussion abe lincoln is the best professor i’ve ever had tech is bad this is a great bot pretty well, actually! i think i’m finally getting the hang of things. the breakout sessions were very engaging, and i really enjoyed the discussion questions one person dominated the full-class discussion, which was annoying. but overall it was a good class they’re fine. problem sets are really helpful, but we haven’t gotten any feedback on them so far so i’m not sure how well i’m actually doing on these. async was okay. it felt superfluous though. it didn’t really have anything to do with what we talked about in live session i feel like we could use an extra TA - it would really help with the problem set feedback turnaround. other than that, things are going well though class is… not going well. i’m feeling a little lost with this week’s material live session was good! lots of lively discussion, which made class go by really fast, which was nice async was pretty repetitive. it felt like a lot of the material was covered multiple times, and then AGAIN in the live session :sleepy: still haven’t gotten any feedback on assignments so far, which is frustrating. they’re pretty straightforward, though, which is nice."\nwe really need to start getting feedback on assignments we’ve turned in. we’re halfway through the semester and i don’t have any grades yet. not okay." class is going well! i feel like i’m understanding the material finally, even though i’m not sure what my grade is yet because we haven’t gotten any grades backyet it was good - it ran half an hour over, which was tough, but the discussion was fun so it didn’t seem like it took as long as it did async felt a little long this week, it didn’t seem super relevant to what we talked about in live session the problem sets have been really difficult. i’ve learned a lot, but they take FOREVER and if i wasn’t working with some other students, i’d be totally lost live sessions have been running late recently, which has been really tough on my schedule (i’m in a different time zone, so going late means cutting into my sleep). if we could keep class to the scheduled time, that would make things much easier. class is going REALLY well right now. i’m really enjoying the recent material, and i’m starting to get the hang of it. i feel like i’m keeping up with everyone else for the first  time i  thought the discussion was really productive, though it did get kind  of tense at one point. once we got past the first reading, though, i thought things got back to  normal. it was okay. i feel like the async for the last couple of weeks hasn’t had anything to do with what we’ve actually talked about in live session, but it has been interesting at least. i’m struggling to see why i need to be watching it, though, since we never end up actually reviewing or talking through it didn’t have any assignments this week, so all good live session hasn’t really had anything to do with the async lectures. i’m not really sure whether live session or async is more relevant to what we’re supposed to be taking out of this class :disappointed: haven\'t gotten any feedback on assignments yet. we\'re halfway through the semester. this is unacceptable live session feels like a waste of time live session runs forever, feels superfluous, doesn\'t relate at all to the things we review in async async and live session have nothing to do with each other live session ran over time this week. it always runs late. i\'m on the east coast, so this means i get much less sleep than i ...

# %%
text = nlp(clean_text)
items = [x.text for x in text.ents]
Counter(items).most_common(10)
# Out:
# [('one', 7),
#  (' ', 5),
#  ('first', 4),
#  ('241', 3),
#  ('this week', 2),
#  ('MIDS', 2),
#  ('TA', 2),
#  ('CNN', 2),
#  ('201', 2),
#  ('205', 2)]

# %%
# 5-10 mins
dictionary = corpora.Dictionary(chats_tokenized)
corpus = [dictionary.doc2bow(text) for text in chats_tokenized]

pickle.dump(corpus, open('corpus_feedback.pkl', 'wb'))
dictionary.save('dictionary_feedback.gensim')

# %%
# dictionary = load_from_text('dictionary_feedback.gensim')

# %%
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=5)
ldamodel.save('feedback_model5t_5p_4w.gensim')
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.029*"session" + 0.025*"really" + 0.025*"async" + 0.016*"discussion"')
# (1, '0.024*"really" + 0.024*"would" + 0.024*"extra" + 0.016*"going"')
# (2, '0.030*"instructor" + 0.030*"assignment" + 0.026*"feedback" + 0.022*"grade"')
# (3, '0.034*"really" + 0.029*"async" + 0.023*"feedback" + 0.020*"assignment"')
# (4, '0.027*"class" + 0.022*"async" + 0.022*"grade" + 0.017*"though"')

# %%
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=10)
ldamodel.save('feedback_model5t_10p_4w.gensim')
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.029*"discussion" + 0.019*"class" + 0.019*"really" + 0.015*"specific"')
# (1, '0.025*"session" + 0.025*"async" + 0.020*"though" + 0.020*"actually"')
# (2, '0.035*"assignment" + 0.024*"async" + 0.023*"feedback" + 0.020*"really"')
# (3, '0.029*"feedback" + 0.027*"class" + 0.025*"really" + 0.023*"might"')
# (4, '0.012*"super" + 0.012*"material" + 0.012*"things" + 0.012*"understanding"')

# %%
NUM_TOPICS = 3
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=20)
ldamodel.save('feedback_model3t_20p_4w.gensim')
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.030*"async" + 0.022*"class" + 0.020*"session" + 0.017*"really"')
# (1, '0.030*"feedback" + 0.021*"grade" + 0.018*"actually" + 0.018*"really"')
# (2, '0.025*"discussion" + 0.023*"really" + 0.023*"async" + 0.021*"class"')

# %%
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=20)
#ldamodel.save('feedback_model4t_20p_6w.gensim')
topics = ldamodel.print_topics(num_words=6)
for topic in topics:
    print(topic)
# Out:
# (0, '0.031*"feedback" + 0.031*"assignment" + 0.027*"going" + 0.024*"grade" + 0.021*"semester" + 0.017*"instructor"')
# (1, '0.042*"really" + 0.027*"though" + 0.024*"discussion" + 0.019*"question" + 0.019*"mobile" + 0.015*"grade"')
# (2, '0.054*"session" + 0.053*"async" + 0.028*"really" + 0.025*"anything" + 0.024*"actually" + 0.019*"talk"')
# (3, '0.023*"class" + 0.015*"async" + 0.015*"frustrate" + 0.015*"would" + 0.015*"could" + 0.015*"video"')
# (4, '0.022*"issue" + 0.022*"might" + 0.017*"instructor" + 0.011*"student" + 0.011*"learn" + 0.011*"quality"')
