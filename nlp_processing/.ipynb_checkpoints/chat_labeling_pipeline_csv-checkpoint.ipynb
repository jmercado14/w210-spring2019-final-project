# %% [markdown]
# ## Chat labeling pipeline

# %%
import pandas as pd
import re
import json
import csv

import nltk
# nltk.download('punkt')
# nltk.download('stopwords')
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
# nltk.download('wordnet')
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer
from spacy.lang.en import English
parser = English()

import gensim
from gensim import corpora
from gensim.summarization.summarizer import summarize
from gensim.models.ldamodel import LdaModel
from gensim.models import Phrases

from pathlib import Path

from operator import itemgetter

import pickle

# %% [markdown]
# ### Ingest raw chat data

# %%
# csv file
chats = pd.read_csv('training_data/feedback_data_for_training.csv')

# %%
chats[1:10]
# Out:
#            source                                      feedback_text  \
# 1  team_generated  i’d ask for more time from the TAs, or try to ...
# 2  team_generated  the way that they encourage lots of class disc...
# 3  team_generated  async is going pretty well, but not super appl...
# 4  team_generated    abe lincoln is the best professor i’ve ever had
# 5  team_generated                                        tech is bad
# 6  team_generated                                this is a great bot
# 7  team_generated  the breakout sessions were very engaging, and ...
# 8  team_generated  one person dominated the full-class discussion...
# 9  team_generated  they’re fine. problem sets are really helpful,...
#
#           topic                       sub_topic
# 1   assignments                 slow turnaround
# 2  live session                 good discussion
# 3         async  disconnected from live session
# 4   instructors                             NaN
# 5    technology                        negative
# 6    technology                        positive
# 7  live session                 good discussion
# 8  live session                      unbalanced
# 9   assignments                 slow turnaround

# %% [markdown]
# ### Clean data

# %%
chats = chats.assign(pred_sub_topic=None)
chats
# Out:
#              source                                      feedback_text  \
# 0    team_generated  i have no idea how i’m doing so far. we’ve tur...
# 1    team_generated  i’d ask for more time from the TAs, or try to ...
# 2    team_generated  the way that they encourage lots of class disc...
# 3    team_generated  async is going pretty well, but not super appl...
# 4    team_generated    abe lincoln is the best professor i’ve ever had
# 5    team_generated                                        tech is bad
# 6    team_generated                                this is a great bot
# 7    team_generated  the breakout sessions were very engaging, and ...
# 8    team_generated  one person dominated the full-class discussion...
# 9    team_generated  they’re fine. problem sets are really helpful,...
# 10   team_generated  async was okay. it felt superfluous though. it...
# 11   team_generated  i feel like we could use an extra TA - it woul...
# 12   team_generated  live session was good! lots of lively discussi...
# 13   team_generated  async was pretty repetitive. it felt like a lo...
# 14   team_generated  still haven’t gotten any feedback on assignmen...
# 15   team_generated  class is going well! i feel like i’m understan...
# 16   team_generated  it was good - it ran half an hour over, which ...
# 17   team_generated  it was good - it ran half an hour over, which ...
# 18   team_generated  async felt a little long this week, it didn’t ...
# 19   team_generated  the problem sets have been really difficult. i...
# 20   team_generated  live sessions have been running late recently,...
# 21   team_generated  i  thought the discussion was really productiv...
# 22   team_generated  it was okay. i feel like the async for the las...
# 23   team_generated  didn’t have any assignments this week, so all ...
# 24   team_generated  live session hasn’t really had anything to do ...
# 25   team_generated  haven't gotten any feedback on assignments yet...
# 26   team_generated            live session feels like a waste of time
# 27   team_generated  live session runs forever, feels superfluous, ...
# 28   team_generated  async and live session have nothing to do with...
# 29   team_generated  live session ran over time this week. it alway...
# ..              ...                                                ...
# 207      class_recs  I prefer a collection of single purpose tools ...
# 208      class_recs  So I don't ever have to have another gd meetin...
# 209      class_recs  She and the co-professor are still figuring it...
# 210      class_recs  Biggest challenge for me was installing Jupyte...
# 211      class_recs  Most of all (and he's been doing this less sin...
# 212      class_recs  Totally agree on the need for zoom/full screen...
# 213      class_recs  No subtitles, and images that are too small to...
# 214      class_recs  For example, when I was professoring, students...
# 215      class_recs  I would add that you should be prepared to pro...
# 216      class_recs  No particular synergy other classes except tha...
# 217      class_recs  He adds supplemental material to the live lect...
# 218      class_recs  The teaching staff does a wonderful job of foc...
# 219      class_recs  instructors were pretty good about walking thr...
# 220      class_recs  the instruction team has to do a TON of prepar...
# 221      class_recs  The materials are VERY synced up between diffe...
# 222      class_recs  we're doing DL in near end of the semester. Bu...
# 223      class_recs                    live sessions are very hands on
# 224      class_recs  my instructors for 261 weren't very good and h...
# 225      class_recs  t's a lot of Spark functional programming but ...
# 226      class_recs  The live sessions were more lectures than disc...
# 227      class_recs  he has a really good approach to working throu...
# 228      class_recs  the async is all theory/intuition (nothing abo...
# 229      class_recs  if you don’t have a mac you might want to inve...
# 230      class_recs  he's a good teacher, as long as you want pract...
# 231      class_recs  While we could get into interesting tangents a...
# 232      class_recs  working through python assignments and the fin...
# 233      class_recs  We have feedback as a class early that lecturi...
# 234      class_recs  Implementation with code is left to the proble...
# 235      class_recs  I was pretty angry about the async quality las...
# 236      class_recs  The assignments can be nasty (but very worthwh...
#
#             topic                       sub_topic pred_sub_topic
# 0     assignments                 slow turnaround           None
# 1     assignments                 slow turnaround           None
# 2    live session                 good discussion           None
# 3           async  disconnected from live session           None
# 4     instructors                             NaN           None
# 5      technology                        negative           None
# 6      technology                        positive           None
# 7    live session                 good discussion           None
# 8    live session                      unbalanced           None
# 9     assignments                 slow turnaround           None
# 10          async  disconnected from live session           None
# 11    assignments                 slow turnaround           None
# 12   live session                 good discussion           None
# 13          async                     low quality           None
# 14    assignments                 slow turnaround           None
# 15    assignments                 slow turnaround           None
# 16   live session                 good discussion           None
# 17   live session            not keeping schedule           None
# 18          async  disconnected from live session           None
# 19    assignments                   too difficult           None
# 20   live session            not keeping schedule           None
# 21   live session                      unbalanced           None
# 22          async  disconnected from live session           None
# 23    assignments                             NaN           None
# 24          async  disconnected from live session           None
# 25    assignments                 slow turnaround           None
# 26   live session                     not helpful           None
# 27   live session                     not helpful           None
# 28          async  disconnected from live session           None
# 29   live session            not keeping schedule           None
# ..            ...                             ...            ...
# 207    technology                             NaN           None
# 208    technology                             NaN           None
# 209    technology                             NaN           None
# 210    technology                             NaN           None
# 211    technology                             NaN           None
# 212    technology                             NaN           None
# 213    technology                             NaN           None
# 214    technology                             NaN           None
# 215    technology                             NaN           None
# 216    technology                             NaN           None
# 217  live session                             NaN           None
# 218   instructors                             NaN           None
# 219  live session                             NaN           None
# 220  live session                             NaN           None
# 221  live session                             NaN           None
# 222    technology                             NaN           None
# 223  live session                             NaN           None
# 224  live session                             NaN           None
# 225    technology                             NaN           None
# 226  live session                             NaN           None
# 227  live session                             NaN           None
# 228         async                             NaN           None
# 229    technology                             NaN           None
# 230  live session                             NaN           None
# 231  live session                             NaN           None
# 232   assignments                             NaN           None
# 233  live session                             NaN           None
# 234   assignments                             NaN           None
# 235         async                             NaN           None
# 236   assignments                             NaN           None
#
# [237 rows x 5 columns]

# %% [markdown]
# ### Apply topic models to chat data

# %%
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)

en_stop = set(nltk.corpus.stopwords.words('english'))

def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

def prepare_document(doc):
    
    tokenized = []
    
    tokens = prepare_text_for_lda(str(doc))
    tokenized.append(tokens)

    # Add bigrams to docs (only ones that appear 20 times or more).
    bigram = Phrases(tokenized, min_count=20)
    for idx in range(len(tokenized)):
        for token in bigram[tokenized[idx]]:
            if '_' in token:
                # Token is a bigram, add to document.
                tokenized[idx].append(token)
        
    return tokenized

# %%
def pred_topic(text):
    model_filename = 'topic_models/full_topic_model.sav'
    topic_model = pickle.load(open(model_filename, 'rb'))
    result = topic_model.predict([text])[0]
    # print(result)
    return result

def pred_sub_topic(text, dictionary, model):
    
    # predict subtopic
    tokens = prepare_document(text)
    
    # print(tokens)
    bow_tokens = dictionary.doc2bow(tokens[0])
    vector = model[bow_tokens]
    #print(vector)
    most_likely = max(vector,key=itemgetter(1))
    vector = sorted(((v,k) for k,v in vector))
    # print (vector)
    
    if (vector[-1][1] == 5):
        if (vector[-2][1] == 7):
            return vector[-3][1]
        return vector[-2][1]
    return vector[-1][1]

# %%
NUM_TOPICS = 14
NUM_PASSES = 300

# load dictionary
dictionary_filename = "topic_dictionaries/%s_dictionary_feedback.gensim" % ("sciences")
dictionary = corpora.Dictionary.load(dictionary_filename)
    
# load model
ldamodel_filename = 'topic_models/%s_model%st_%sp.gensim' % ("sciences", str(NUM_TOPICS), str(NUM_PASSES))
model = LdaModel.load(ldamodel_filename)

# %%
chats[1:5]
# Out:
#            source                                      feedback_text  \
# 1  team_generated  i’d ask for more time from the TAs, or try to ...
# 2  team_generated  the way that they encourage lots of class disc...
# 3  team_generated  async is going pretty well, but not super appl...
# 4  team_generated    abe lincoln is the best professor i’ve ever had
#
#           topic                       sub_topic pred_sub_topic
# 1   assignments                 slow turnaround           None
# 2  live session                 good discussion           None
# 3         async  disconnected from live session           None
# 4   instructors                             NaN           None

# %%
chats['feedback_text'][1]
# Out:
# 'i’d ask for more time from the TAs, or try to bring  on some additional TAs so they can turn around assignments faster'

# %%
for i in range(len(chats)):
    # chat['pred_topic'] = pred_topic(chat['topic']) if chat['topic'] == 'miscellaneous' else None
    chats['pred_sub_topic'][i] = pred_sub_topic(chats['feedback_text'][i], dictionary, model)
    
chats[1:10]
# Out:
#            source                                      feedback_text  \
# 1  team_generated  i’d ask for more time from the TAs, or try to ...
# 2  team_generated  the way that they encourage lots of class disc...
# 3  team_generated  async is going pretty well, but not super appl...
# 4  team_generated    abe lincoln is the best professor i’ve ever had
# 5  team_generated                                        tech is bad
# 6  team_generated                                this is a great bot
# 7  team_generated  the breakout sessions were very engaging, and ...
# 8  team_generated  one person dominated the full-class discussion...
# 9  team_generated  they’re fine. problem sets are really helpful,...
#
#           topic                       sub_topic pred_sub_topic
# 1   assignments                 slow turnaround              7
# 2  live session                 good discussion              7
# 3         async  disconnected from live session              7
# 4   instructors                             NaN              7
# 5    technology                        negative              7
# 6    technology                        positive              7
# 7  live session                 good discussion              1
# 8  live session                      unbalanced              7
# 9   assignments                 slow turnaround              7

# %% [markdown]
# ### Export appended data

# %%
with open('data_outputs/updated_training_data.csv', 'w') as f:  # Just use 'w' mode in 3.x
    w = csv.DictWriter(f, chats[1].keys())
    w.writeheader()
    for chat in chats:
        w = csv.DictWriter(f, chat.keys())
        w.writerow(chat)

# %%
chats.to_csv('data_outputs/updated_training_data.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Chat summaries by topic

# %% [markdown]
# ### Generate topic summaries

# %%
topics = set()

for chat in chats:
    topics.add(chat['topic'])
    
topics
# Out:
# {'assignment', 'live session', 'technology'}

# %%
for topic in topics:
    print ("Processing", topic)
    topic_subset = [d for d in chats if d['topic'] == topic]
    topic_text = []
    for chat in topic_subset:
        topic_text.append(chat['reponse_full'])
    print(topic_text)
    
    
    s = '. '
    text = s.join(topic_text)
    text = re.sub("\.+", ".", text)
    text = re.sub("\n", "", text)
    # print(text)
    print(summarize(text))
    print('\n')
# Out:
# Processing live session
# ["Groups keep going over their alotted time to present and the instructors don't interceed. I'd ask them to be more strict and maybe tell the students when they have 5 and 1 minute left I'd ask them to cut the groups off when they exceed their time"]
#
#
#
# Processing technology
# ["I personally am a huge fan of Zoom, and I am so glad Zoom has officially replaced Adobe Connect in ISVC. Adobe Connect audio and video quality was my major concern and I am excited that I can have a great online classroom experience with the transition to Zoom. It's not 100% clear to me when the assignments are due and where to submit them. I understand Jane's motivation to want to use GitHub but the information on GitHub is not in sync with the information on ISVC. If Jane can make sure everything is aligned and in agreement, that would be a huge help! Office hour Zoom recordings are incredibly helpful. I particularly like that I can benefit from a different instructors' office hours as well. Please continue to record office hours!", 'I personally am a huge fan of Zoom, and I am so glad Zoom has officially replaced Adobe connect in ISVC. Adobe connect audio and video quality was my major concern and I am excited that I can have a great online classroom experience with the transition to Zoom. It’s not 100% clear to me when the assignments are due and where to submit them. I understand Jane’s motivation to want to use GitHub but the information on GitHub is not in sync with the information on ISVC. If jane can make sure everything is aligned and in agreement, that would be a huge help! Office hour Zoom recordings are incredibly helpful! I particularly like that I can benefit from a different instructors’ office hours as well. Please continue to record office hours.', 'I personally am a huge fan of Zoom, and I am so glad Zoom has officially replaced Adobe Connect in ISVC. Adobe Connect audio and video quality was my major concern and I am excited that I can have a great online classroom experience with the transition to Zoom. It’s not 100% clear to me when the assignments are due and where to submit them. I understand Jane’s motivation to want to use GitHub but the information on GitHub is not in sync with the information on ISVC. If Jane can make sure everything is aligned and in agreement, that would be a huge help! Office hour Zoom recordings are incredibly helpful. I particularly like that I can benefit from different instructors’ office hours as well. Please continue to record office hours']
# I understand Jane's motivation to want to use GitHub but the information on GitHub is not in sync with the information on ISVC.
# I particularly like that I can benefit from a different instructors' office hours as well.
# I understand Jane’s motivation to want to use GitHub but the information on GitHub is not in sync with the information on ISVC.
# I understand Jane’s motivation to want to use GitHub but the information on GitHub is not in sync with the information on ISVC.
#
#
# Processing assignment
# ['The instructions for each assignment have been very clear, which has helped keep me on the right track as I worked through each one.It would be great to get feedback on assignments sooner, so I could learn from my mistakes and apply that to future assignments before they’re due.The links to assignments in ISVC are broken.']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-1420744b7aeb> in <module>
#      13     text = re.sub("\n", "", text)
#      14     # print(text)
# ---> 15     print(summarize(text))
#      16     print('\n')
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/summarization/summarizer.py in summarize(text, ratio, word_count, split)
#     426     # If only one sentence is present, the function raises an error (Avoids ZeroDivisionError).
#     427     if len(sentences) == 1:
# --> 428         raise ValueError("input must have more than one sentence")
#     429
#     430     # Warns if the text is too short.
#
# ValueError: input must have more than one sentence

# %% [markdown]
# ### Write to file
